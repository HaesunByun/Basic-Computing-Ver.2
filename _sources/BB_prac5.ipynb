# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK5: 리스트

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 문제의 소스코드를 작성하여 결과가 정확하게 나오면 etl>모듈>과제>에 제출하여야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 etl>모듈>과제에 설정된 기한을 확인하여 주시기 바랍니다.(일반적으로 수업당일 자정까지)</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 상품재고관리: 추가
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명을 입력받아 product에 추가하는 프로그램을 작성하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 사과
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 추가상품명:
# 사과 추가 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '사과']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 컴퓨터
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 추가상품명:
# 컴퓨터 추가 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '컴퓨터']
# ==========================================================================================
# ```

# %%
print('상품재고관리 프로그램')
print()
product = '커피, 우유, 바나나, 감귤, 화장지, 장갑, 이불, 베개, 장난감, 음료수, 빵'.split(', ')
print('현재 상품 리스트')
print(product)
print('='*90)

#TODO

# %% [markdown]
# ### Problem: 상품재고관리: 삽입
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명과 위치를 입력받아 product의 해당위치에 상품명을 삽입하는 프로그램을 작성하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 사과
# 3
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 삽입상품명:
# 삽입위치:
# 사과 삽입 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '사과', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 컴퓨터
# 2
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 삽입상품명:
# 삽입위치:
# 컴퓨터 삽입 완료
#
# 현재 상품 리스트
# ['커피', '우유', '컴퓨터', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```

# %%
print('상품재고관리 프로그램')
print()
product = '커피, 우유, 바나나, 감귤, 화장지, 장갑, 이불, 베개, 장난감, 음료수, 빵'.split(', ')
print('현재 상품 리스트')
print(product)
print('='*90)

#TODO

# %% [markdown]
# ### Problem: 상품재고관리: 삭제
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명을 입력받아 product에서 삭제하는 프로그램을 작성하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 감귤
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 삭제상품명:
# 감귤 삭제 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 컴퓨터
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 삭제상품명:
# 컴퓨터 검색 안됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```

# %%
print('상품재고관리 프로그램')
print()
product = '커피, 우유, 바나나, 감귤, 화장지, 장갑, 이불, 베개, 장난감, 음료수, 빵'.split(', ')
print('현재 상품 리스트')
print(product)
print('='*90)

#TODO

# %% [markdown]
# ### Problem: 상품재고관리: 검색
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명을 입력받아 product에서 검색하는 프로그램을 작성하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 화장지
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 검색상품명:
# 화장지 검색 됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 컴퓨터
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 검색상품명:
# 컴퓨터 검색 안됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```

# %%
print('상품재고관리 프로그램')
print()
product = '커피, 우유, 바나나, 감귤, 화장지, 장갑, 이불, 베개, 장난감, 음료수, 빵'.split(', ')
print('현재 상품 리스트')
print(product)
print('='*90)

#TODO

# %% [markdown]
# ### Problem: 상품재고관리: 정렬
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 오름차순 또는 내림차순으로 정렬하는 프로그램을 작성하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 1
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 오름차순(1) 내림차순(2):
#
# 현재 상품 리스트
# ['감귤', '바나나', '베개', '빵', '우유', '음료수', '이불', '장갑', '장난감', '커피', '화장지']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 2
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 오름차순(1) 내림차순(2):
#
# 현재 상품 리스트
# ['화장지', '커피', '장난감', '장갑', '이불', '음료수', '우유', '빵', '베개', '바나나', '감귤']
# ==========================================================================================
# ```

# %%
print('상품재고관리 프로그램')
print()
product = '커피, 우유, 바나나, 감귤, 화장지, 장갑, 이불, 베개, 장난감, 음료수, 빵'.split(', ')
print('현재 상품 리스트')
print(product)
print('='*90)

#TODO

# %% [markdown]
# ### Problem: 상품재고관리: 종합
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명을  추가, 삽입, 삭제, 검색, 정렬하는 상품재고관리 프로그램을 작성하시오.
#
# 작업번호는 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5)이며 숫자로 입력합니다.
# 상품명은 문자열로 입력합니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 1
# 사과
# 2
# 배
# 4
# 3
# 장난감
# 4
# 베개
# 4
# 피아노
# 5
# 1
# 5
# 2
# 0
# ```
#
# Output Sample
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 추가상품명:
# 사과 추가 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 삽입상품명:
# 삽입위치:
# 배 삽입 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '배', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 삭제상품명:
# 장난감 삭제 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '배', '화장지', '장갑', '이불', '베개', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 검색상품명:
# 베개 검색 됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '배', '화장지', '장갑', '이불', '베개', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 검색상품명:
# 피아노 검색 안됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '배', '화장지', '장갑', '이불', '베개', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 오름차순(1) 내림차순(2):
#
# 현재 상품 리스트
# ['감귤', '바나나', '배', '베개', '빵', '사과', '우유', '음료수', '이불', '장갑', '커피', '화장지']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 오름차순(1) 내림차순(2):
#
# 현재 상품 리스트
# ['화장지', '커피', '장갑', '이불', '음료수', '우유', '사과', '빵', '베개', '배', '바나나', '감귤']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 프로그램을 종료합니다.
#
# ```

# %%
print('상품재고관리 프로그램')

product = '커피, 우유, 바나나, 감귤, 화장지, 장갑, 이불, 베개, 장난감, 음료수, 빵'.split(', ')

while True:
  print()
  print('현재 상품 리스트')
  print(product)
  print('='*90)
  print()

  #TODO

# %% [markdown]
# ### Problem: 오늘의 명언
#
# 😄 아래의 명언을 리스트로 저장한 후, 명언 가운데 하나를 랜덤하게 골라서 출력하는 프로그램을 작성하시오.
#
#
# ```
# 꿈을 지녀라. 그러면 어려운 현실을 이길 수 있다.
# 고생없이 얻을 수 있는 진실로 귀중한 것은 하나도 없다.
# 사람은 사랑할 때 누구나 시인이 된다.
# 시작이 반이다.
# 나는 사랑으로 내가 이해하는 모든 것들을 이해한다.
# ```
# ---
#
# <font color='blue'>`test case-1`</font>
#
#
# Output Sample
#
# ```
# 오늘의 명언: 사람은 사랑할 때 누구나 시인이 된다.
# ```
#
# <font color='blue'>`test case-2`</font>
#
#
# Output Sample
#
# ```
# 오늘의 명언: 꿈을 지녀라. 그러면 어려운 현실을 이길 수 있다.
# ```

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem: (스스로) 월 영문으로 출력하기
# 😄 숫자 월을 입력받아 그것에 대한 영문 월을 출력하시오. 주어지는 리스트변수 months를 활용하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 3
# ```
# Output Sample
# ```
# 월을 입력하세요(1~12):
# 입력된 월은 March 입니다.
# ```
# ---
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 7
# ```
# Output Sample
# ```
# 월을 입력하세요(1~12):
# 입력된 월은 July 입니다.
# ```

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August',\
          'September', 'October', 'November', 'December']

# %% [markdown]
# ### Problem: (함께) 리스트 활용 칼로리 계산기
# 😄 체중(자연수, kg), 운동시간(자연수, 분), 운동종목을 입력받아 칼로리를 계산하는 프로그램을 작성하시오. 주어지는 리스트 ex_list, ex_Mets를 활용하시오. 리스트에 없는 운동종목을 입력한 경우 '아직 포함되지 않은 운동종목입니다.'를 출력합니다.
#
# ```
# METs(대사당량) 기준
# 걷기 : 4METs     조깅 : 7METs
# 계단 : 5METs     수영 : 9METs
#
# 칼로리 =((METs * 3.5 * 체중(kg)) /200)*운동시간(분)
#
# ```
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 60
# 10
# 걷기
# ```
# Output Sample
# ```
# 체중(kg):
# 운동시간(m):
# ['걷기', '조깅', '계단오르기', '수영']
# 운동종목:
# 걷기 10분은 42.0kcal 소모
# ```
# ---
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 60
# 10
# 요가
# ```
# Output Sample
# ```
# 체중(kg):
# 운동시간(m):
# ['걷기', '조깅', '계단오르기', '수영']
# 운동종목:
# 아직 포함되지 않은 운동종목입니다.
# ```

# %%
ex_list=['걷기', '조깅', '계단오르기', '수영']
ex_Mets=[   4,     7,        5,        9]

#TODO

# %% [markdown]
# ### Problem: (스스로) 동이름만 출력하기
# 😄 구 이름과 동 이름이 한칸씩 공백을 두고 입력됩니다. 그 중 동 이름만 출력하는 프로그램을 작성하시오.
#
# `hint`
# ```
# 문자열->리스트로 만들때는 문자열.split()
# 리스트->문자열로 만들때는 ' '.join(리스트변수명) : 아이템마다 ' '을 삽입하면서 문자열로 만들어준다.
# ```
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 강동구 노원구 용산구 상암동 서울시 논현동 가리봉동 평창동 중구 중동 숭구리당당숭당동
# ```
# Output Sample
# ```
# Input:
# 동이름: 상암동 논현동 가리봉동 평창동 중동 숭구리당당숭당동
# ```
# <font color='blue'>`test case-2`</font>
# ---
# Input Sample
# ```
# 우이동 공릉동 부산시 사하구 전라남도 명동 광주시 파이동 썬동 머신러닝
# ```
# Output Sample
# ```
# Input:
# 동이름: 우이동 공릉동 명동 파이동 썬동
# ```

# %% [markdown]
# ### Problem: (함께) 문장 내 단어 출력하기
#
# 😄 문장을 입력 받아 문장 내 모든 단어의 list를 출력하는 프로그램을 작성하시오.
# 출력 시 관사(a, an, the)는 대소문자 모두 제외하시오. 마침표(.)는 항상 마지막에만 들어오며 마침표도 제외하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# A gift in season is a double favor to the needy.
# ```
# Output Sample
# ```
# Input:
# Output: ['gift', 'in', 'season', 'is', 'double', 'favor', 'to', 'needy']
# ```
# <font color='blue'>`test case-2`</font>
# ---
# Input Sample
# ```
# I wish you all the best and look on the bright side.
# ```
# Output Sample
# ```
# Input:
# Output: ['I', 'wish', 'you', 'all', 'best', 'and', 'look', 'on', 'bright', 'side']
# ```

# %% [markdown]
# ### Problem: (스스로) 점수 입력 받아 합구하기
#
# 😄 이름과 점수가 컴마로 구분되어 입력됩니다. 점수의 합을 출력하는 프로그램을 작성하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 영희,철수,미나
# 90,80,95
# ```
# Output Sample
# ```
# 이름:
# 점수:
# Sum: 265
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 지성,연아,흥민
# 90,90,95
# ```
# Output Sample
# ```
# 이름:
# 점수:
# Sum: 275
# ```

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: 동전 최소 개수
# 😄금액을 입력받아 최소 동전의 개수를 출력하는 코드를 작성하시오. 단, 금액은 10000원 이하, 10의 배수로 입력하고, 500원, 100원, 50원, 10원의 동전이 무한개 있다고 가정한다. 동전 종류를 리스트로 만들어 활용하세요.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 9820
# ```
# Output Sample
# ```
# 금액:
# 최소 동전 개수: 24
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 760
# ```
# Output Sample
# ```
# 금액:
# 최소 동전 개수: 5
# ```

# %% [markdown]
# ### Problem: 지역구 이름 정렬하기
# 😄 다음 구이름을 정렬하여 출력하는 프로그램을 작성하시오
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 강동구 노원구 용산구 중구 관악구 중랑구 동대문구 서대문구
# ```
# Output Sample
# ```
# 입력:
# 정렬전: ['강동구', '노원구', '용산구', '중구', '관악구', '중랑구', '동대문구', '서대문구']
# 정렬후: ['강동구', '관악구', '노원구', '동대문구', '서대문구', '용산구', '중구', '중랑구']
# ```

# %% [markdown]
# ### Problem: 컴또복권번호 리스트로 만들기
# 😄 0~9까지의 숫자 가운데 중복되지 않은 4개의 정수를 랜덤으로 생성해 리스트로 만들어 출력하는 프로그램을 작성하시오. 랜덤이므로 Output Sample의 숫자는 아래와 다를 수 있습니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# 컴또복권번호: [7, 4, 3, 6]
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Output Sample
# ```
# 컴또복권번호: [9, 5, 0, 3]
# ```

# %% [markdown]
# ### Problem: 주소 슬라이싱하기
# 😄 '시', '구', '동', '로' 등의 주소 데이터만 슬라이싱하여 출력하는 프로그램을 작성하시오. 주소는 '동'이나 '로'로 끝나며 '시'-'구'-'동' 또는 '시'-'구'-'로'의 순서가 항상 지켜진다고 가정한다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 02-334-0000 서울시 노원구 가즈아로 낙엽 서울시 관악구 강감찬로 콜라 02-3334-1200 서울시 강남구 섬그늘로 서울시 노원구 경춘선숲길 상계동 02-1124-5670
# ```
# Output Sample
# ```
# Input:
# Output: ['서울시 노원구 가즈아로', '서울시 관악구 강감찬로', '서울시 강남구 섬그늘로', '서울시 노원구 상계동']
# ```
# <font color='blue'>`test case-2`</font>
# ---
# Input Sample
# ```
# 010-342-1234 경기 가을단풍 인천시 남구 벚꽃로 벚꽃길 이쁘다 광주시 남구 무등산 수박 진월동 부산광역시 서구 해운대로 부산행
# ```
# Output Sample
# ```
# Input:
# Output: ['인천시 남구 벚꽃로', '광주시 남구 진월동', '부산광역시 서구 해운대로']
#
# ```

# %% [markdown]
# ### Problem: Dragon realm
# 😄 학교 캠퍼스를 돌아다니다가 드래곤을 만났습니다. 당신은 드래곤과 싸워야 합니다. 재미있는 아이디어로 게임을 완성해주세요.
#
# 아이디어 예)
# - 당신은 총 6번 공격할 수 있습니다.
# - Dragon의 초기 체력은 100입니다.
# - 당신의 공격력은 1~30사이의 숫자 중 무작위로 선택된 하나의 값이며 그 값만큼 Dragon의 체력을 소진시킬 수 있습니다.
# - Dragon의 체력이 0 이하가 되면 6번 공격을 채우지 않았어도 공격을 멈춰야 하며 당신은 승리자가 됩니다.
# - 6번의 공격 이후 Dragon의 체력이 0 이하이면 당신은 승리자가 되지만, 0보다 크면 당신은 Dragon에게 잡아 먹히게 됩니다.

# %%
attack = ['1.무작정 공격', '2.음식으로 유인', '3.앞발차기', '4.가위바위보' ]
print(attack)
attack_num = int(input('공격방법을 선택해주세요.(1~4)'))
print(f'당신은 {attack[attack_num-1]}을 선택하셨군요!')

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---
