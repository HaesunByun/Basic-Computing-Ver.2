# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK2: 기본 자료형과 변수

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 문제의 소스코드를 작성하여 결과가 정확하게 나오면 etl>모듈>과제>에 제출하여야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 etl>모듈>과제에 설정된 기한을 확인하여 주시기 바랍니다.(일반적으로 수업당일 자정까지)</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 수식으로 표현해보기
#
# 😄다음을 수식으로 표현해보고 결과를 출력하시오.
#   - 정수 10과 정수 20을 더하시오.
#   - 정수 30에서 정수 5를 빼시오.
#   - 정수 15와 실수 7.0을 곱하시오.
#   - 정수 2를 정수 4로 나누시오.
#   - 실수 2.0을 실수 4.0으로 나누시오.
#   - 정수 50을 정수 4로 나눈 몫을 정수로 구하시오.
#   - 정수 50을 정수 4로 나눈 나머지를 구하시오.
#   - 정수 10을 정수 3으로 지수승하시오.
#
# ---
# Output
# ```
# 30
# 25
# 105.0
# 0.5
# 0.5
# 12
# 2
# 1000
# ```

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem:(함께) 수식으로 표현해보기
# 😄 다음 수식을 코드로 표현해보고 결과를 출력하시오.
#
# ---
#
# $ 3^0 * 8^\frac{2}{3}$
#
# Output Result
# ```
# 4.0
# ```

# %% [markdown]
# :::{admonition} Tip
# :class: tip
#
# - 소수점 이하 원하는 자릿수까지만 표현하기 위한 두 가지 방법을 소개한다.
#   - `round(value, n)` n은 자릿수이다. n을 생략하면 반올림하여 정수로 출력한다.
#   - `f'{value:.nf}'` n은 자릿수이며 생략할 수 없다. 정수로 출력하고 싶다면 n자리에 0을 넣는다.
#   :::

# %%
print(round(3.141592, 3))
print(round(3.141592))
print(round(3.541592))

# %%
print(f'{3.141592:.0f}')

# %% [markdown]
# ### Problem: (스스로) 변수활용하여 수식으로 표현해보기
# 😄 x는 3이다. 변수 x를 활용하여 수식을 작성해보고 y를 출력하시오.
#
# $ y=[\{(𝑥^2−2𝑥)−6\}×2]+(3𝑥−3)÷2 $
#
# Output Result
# ```
# Output: -3.0
# ```

# %% [markdown]
# ### Problem: (스스로) 마트 지불가격 계산하기
# 😄 우유의 가격은 1850원이다. 계란 한판의 가격은 4000원이다. 모든 제품은 5%를 할인해준다. 우유 2개, 계란 한판을 구입했을 때 지불해야 할 가격을 변수 milk, egg, discount를 활용하여 코드로 작성하고 결과를 출력하시오.
#
# ---
#
# Output Result
# ```
# Output: 7315.0
# ```

# %% [markdown]
# ### Problem: (함께) 화씨온도 변환하기
# 😄화씨온도 100을 변수에 저장한 후 섭씨온도 변환 공식을 적용하여 출력하시오. 온도 변환공식은 아래와 같습니다.
#
# ---
#
# ```
# c = 5.0/9.0*(f-32.0)
# ```
# Output Sample
# ```
# C: 37.78
# ```

# %% [markdown]
# ### Problem: (스스로) 섭씨온도 변환하기
# 😄섭씨온도 50을 변수에 저장한 후 화씨온도 변환 공식을 적용하여 출력하시오.  온도 변환공식은 아래와 같습니다.
# ```
# f = 9.0/5.0*c+32.0
# ```
# Output Sample
# ```
# F: 122.0
# ```

# %% [markdown]
# ### Problem: (스스로) 성적 출력하기
# 😄 국어, 영어, 컴퓨팅 점수를 변수에 저장하고 합계와 평균을 구하여 출력하시오.
# ```
# 국어: 99
# 영어: 85
# 컴퓨팅: 90
# ```
# Output Sample
# ```
# 합계: 274, 평균: 91.33
# ```

# %% [markdown]
# ### Problem: (스스로) 원영에게 인사하기
# 😄 변수에 이름을 저장한 후 Output Sample과 같이 출력하시오.
# ```
# name = '장원영'
# ```
# Output Sample
# ```
# Output: 장원영님 안녕하세요!
# ```

# %% [markdown]
# ### Problem: (스스로) 문자열 연속 출력하기
#
# 😄 변수 name에 '지수'를 넣고 변수를 활용하여 3번 연속으로 '지수야 반가워'를 출력하시오.
#
# Output Sample
# ```
# Output: 지수야 반가워 지수야 반가워 지수야 반가워
# ```

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: 문자열 출력하기
# 😄 다음 문자열을 따옴표까지 모두 나오도록 출력하시오.
#
# ---
# Output
#
# ```
# '끝날 때 까지 "끝"난게 아니다.'
# ```

# %% [markdown]
# ### Problem: 아르바이트 급여 계산 프로그램
# 😄 다음 값들을 변수에 저장한 후 급여 금액을 출력하시오. 또한 한달(4주) 기준의 금액도 출력하시오.
# ```
# 주간 시급: 9,500원
# 야간근무는 주간 시급에 1.5배
# 주간근무(9:00~18:00, 점심 1시간 제외, 월~금): 8시간
# 야간근무(18:00~20:00, 토~일): 2시간
# ```
# ---
# Output
#
# ```
# 1주 급여: 437000원
# 한달 급여: 1748000원
# ```

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---
