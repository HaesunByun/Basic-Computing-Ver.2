# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK8: 함수2

# %% [markdown]
# **<font color='red'>안내</font>**
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 문제의 소스코드를 작성하여 결과가 정확하게 나오면 etl>코딩수업>엘리스코딩 플랫폼의 해당 주차에 제출해서 점수를 받으셔야 과제제출로 인정됩니다.</font>**
# - **<font color='red'>제출기한은 엘리스코딩 플랫폼의 해당 주차에 설정된 기한을 확인하여 주시기 바랍니다.(일반적으로 수업당일 자정까지)</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: Dragon realm 확장
# 😄 불을 내뿜는 드래곤을 만났습니다. 당신은 드래곤과 싸워야 합니다. 재미있는 아이디어로 게임을 완성해주세요.
#
# 아이디어 예)
# - 당신은 총 6번 공격할 수 있습니다.
# - Dragon의 초기 체력은 100입니다.
# - 당신의 공격력은 1~30사이의 숫자 중 무작위로 선택된 하나의 값이며 그 값만큼 Dragon의 체력을 소진시킬 수 있습니다.
# - Dragon의 체력이 0 이하가 되면 6번 공격을 채우지 않았어도 공격을 멈춰야 하며 당신은 승리자가 됩니다.
# - 6번의 공격 이후 Dragon의 체력이 0 이하이면 당신은 승리자가 되지만, 0보다 크면 당신은 Dragon에게 잡아 먹히게 됩니다.

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### (함께)영화관 좌석 초기화

# %% [markdown]
# 😄컴기시네마에는 총 3개의 상영관이 있습니다. 1관은 (8행,10열)을 가지고 있어서 관람객 80명을 받을 수 있고, 2관은 (7행,7열), 3관은 (4행, 5열)을 가지고 있는 리클라이너 상영관입니다.
# 상영관을 입력받아 2차원 리스트로 Output Sample과 같이 좌석을 초기화하고 리스트를 반환하는 함수 movie_seat_reset()을 만드시오. 단, 직접 입력하여 만들면 안됩니다.
#
# Input Sample
# ```
# 1
# ```
#
# Output Sample
# ```
# Input:
# 상영관 1관 좌석이 초기화 되었습니다.
# [['□', '□', '□', '□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□', '□', '□', '□']]
# ```
#
# Input Sample
# ```
# 2
# ```
#
# Output Sample
# ```
# Input:
# 상영관 2관 좌석이 초기화 되었습니다.
# [['□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□', '□', '□']]
# ```
#
# Input Sample
# ```
# 3
# ```
#
# Output Sample
# ```
# Input:
# 상영관 3관 좌석이 초기화 되었습니다.
# [['□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□'],
#  ['□', '□', '□', '□', '□']]
# ```

# %%
# 이 함수는 영화관 초기 정보입니다.
# 한줄 한줄 코드는 조교님이 설명합니다.
def info_init():
  global a_rows, seat_info, seat_list
  a_rows = string.ascii_uppercase  # 이 라인은 다음문제에서 사용되지만 초기화를 위해 여기 넣었습니다.
  seat_info = {'1': (8,10), '2': (7,7), '3':(4,5)}
  seat_list= {'1': list(), '2': list(), '3':list()}

info_init()

# %%
# 이 문제는 함께 풀어보는 문제이지만
# 어떻게 해결할지 스스로 잠깐 생각해봅시다.
def movie_seat_reset(place):










  print(f'상영관 {place}관 좌석이 초기화 되었습니다.')

place = input('Input: ')
movie_seat_reset(place)
print(seat_list[place])

# %% [markdown]
# ### (스스로) 영화관 좌석 현황 출력

# %% [markdown]
# 😄상영관의 좌석 예약 현황을 보여하는 show_seat() 함수를 만드시오. 빈 좌석은 '□'로 표시되어 있고, 예약된 좌석은 '■'로 표시됩니다. 현재는 예약된 좌석이 없어 모두 '□'로 표시됩니다. 모든 행앞에는 알파벳이 먼저 출력되어야 합니다. 마지막줄에는 현재 '예약된 좌석수/전체 좌석수'가 출력되어야 합니다.
#
# Test case-1
#
# Input Sample
# ```
# 1
# ```
#
# Output Sample
# ```
# Input:
# A□□□□□□□□□□
# B□□□□□□□□□□
# C□□□□□□□□□□
# D□□□□□□□□□□
# E□□□□□□□□□□
# F□□□□□□□□□□
# G□□□□□□□□□□
# H□□□□□□□□□□
# 0/80
# ```
#
# Test case-2
#
# Input Sample
# ```
# 2
# ```
#
# Output Sample
# ```
# Input:
# A□□□□□□□
# B□□□□□□□
# C□□□□□□□
# D□□□□□□□
# E□□□□□□□
# F□□□□□□□
# G□□□□□□□
# 0/49
# ```
#
# Test case-2
#
# Input Sample
# ```
# 3
# ```
#
# Output Sample
# ```
# Input:
# A□□□□□
# B□□□□□
# C□□□□□
# D□□□□□
# 0/20
# ```

# %%
import string

def show_seat(place):
  global a_rows
  a_rows = string.ascii_uppercase #여기까지는 조교님이 설명합니다.











  pass

place = input('Input: ')
show_seat(place)
# Out:
# Input: 3
# A□□□□□
# B□□□□□
# C□□□□□
# D□□□□□
# 0/20

# %% [markdown]
# ### (스스로) 영화관 좌석 예약

# %% [markdown]
# 😄다음은 현재 좌석현황을 보여 준 후, 영화관 좌석을 입력받아 표시하는 resvd_seat() 함수를 작성하시오. 예약좌석은 알파벳 1글자와 숫자로 구성되어 있습니다.
#
# Test case-1
#
# ```
# 2
# D2
# ```
#
# Output Result
# ```
# 상영관 선택:
# A□□□□□□□
# B□□□□□□□
# C□□□□□□□
# D□□□□□□□
# E□□□□□□□
# F□□□□□□□
# G□□□□□□□
# 0/49
# 예약좌석:
# A□□□□□□□
# B□□□□□□□
# C□□□□□□□
# D□■□□□□□
# E□□□□□□□
# F□□□□□□□
# G□□□□□□□
# 1/49
# ```
#
# Test case-1
#
# ```
# 3
# D3
# ```
#
# Output Result
# ```
# 상영관 선택:
# A□□□□□□□
# B□□□□□□□
# C□□□□□□□
# D□■□□□□□
# E□□□□□□□
# F□□□□□□□
# G□□□□□□□
# 1/49
# 예약좌석:
# A□□□□□□□
# B□□□□□□□
# C□□□□□□□
# D□■■□□□□
# E□□□□□□□
# F□□□□□□□
# G□□□□□□□
# 2/49
# ```

# %%
def resvd_seat(place):






  pass

place = input('상영관 선택: ')
show_seat(place)
resvd_seat(place)
show_seat(place)

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---
