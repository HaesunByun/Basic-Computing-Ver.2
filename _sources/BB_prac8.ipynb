# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK8: 함수

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 문제의 소스코드를 작성하여 결과가 정확하게 나오면 etl>모듈>과제>에 제출하여야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 etl>모듈>과제에 설정된 기한을 확인하여 주시기 바랍니다.(일반적으로 수업당일 자정까지)</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ### 데이터 입력과 출력 예
# 😄문자열을 입력받아 출력하시오.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: 즐거워
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# Say! I can do it!
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: Say! I can do it!
# ```

# %%
input_data = input('문자열: ')
print(f'출력결과: {input_data}')
# Out:
# 문자열: Say! I can do it!
# 출력결과: Say! I can do it!

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 상품재고관리: 머리말함수
# 😄 상품재고관리 프로그램에서 머리말을 출력하는 proName()함수와 preface()함수를 정의하고 호출하여 Output Sample과 같이 출력해보세요. Output Sample의 === 줄 아래에는 (자동 삭제되어 여기에서는 보이지는 않지만) 빈 하나의 줄이 있습니다.
# 함수 정의와 호출의 이해를 위해 이 문제는 코드를 드립니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
#
# ```

# %%
def proName():
  global product
  print('상품재고관리 프로그램')
  product = '커피, 우유, 바나나, 감귤, 화장지, 장갑, 이불, 베개, 장난감, 음료수, 빵'.split(', ')

def preface():
  print()
  print('현재 상품 리스트')
  print(product)
  print('='*90)
  print()

proName()
preface()

# %% [markdown]
# ### Problem: 상품재고관리: 추가함수
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명을 입력받아 product에 추가하는 함수 item_apnd()를 정의하고, 호출하여 Output Sample과 같이 출력해보세요. 입력과 출력은 함수 안에서 이루어집니다. 머리말 부분을 출력할때에는 앞서 정의한 proName(), preface()함수를 이용하세요.
#
#
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 사과
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 추가상품명:
# 사과 추가 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '사과']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 컴퓨터
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 추가상품명:
# 컴퓨터 추가 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '컴퓨터']
# ==========================================================================================
# ```

# %%
def item_apnd():
  #Todo


proName()
preface()
item_apnd()
preface()

# %% [markdown]
# ### Problem: 상품재고관리: 삽입함수
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명과 위치를 입력받아 product의 해당위치에 상품명을 삽입하는 함수 item_inst()를 정의하고, 호출하여 Output Sample과 같이 출력해보세요. 머리말 부분을 출력할때에는 앞서 정의한 preface()함수를 이용하세요.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 사과
# 3
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 삽입상품명:
# 삽입위치:
# 사과 삽입 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '사과', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 컴퓨터
# 2
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 삽입상품명:
# 삽입위치:
# 컴퓨터 삽입 완료
#
# 현재 상품 리스트
# ['커피', '우유', '컴퓨터', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```

# %%
#Todo
def


proName()
preface()
item_inst()
preface()

# %% [markdown]
# ### Problem: 상품재고관리: 삭제함수
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명을 입력받아 product에서 삭제하는 함수 item_remv()를 정의하고, 호출하여 Output Sample과 같이 출력해보세요. 머리말 부분을 출력할때에는 앞서 정의한 preface()함수를 이용하세요.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 감귤
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 삭제상품명:
# 감귤 삭제 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 컴퓨터
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 삭제상품명:
# 컴퓨터 검색 안됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```

# %%
#Todo



proName()
preface()
item_remv()
preface()

# %% [markdown]
# ### Problem: 상품재고관리: 검색함수
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명을 입력받아 product에서 검색하는 함수 item_search()를 정의하고, 호출하여 Output Sample과 같이 출력해보세요. 머리말 부분을 출력할때에는 앞서 정의한 preface()함수를 이용하세요.작성하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 화장지
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 검색상품명:
# 화장지 검색 됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 컴퓨터
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 검색상품명:
# 컴퓨터 검색 안됨
#
# 현재 상품 리스트
# ['커피', '우유', '컴퓨터', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# ```

# %%
#Todo




proName()
preface()
item_search()
preface()

# %% [markdown]
# ### Problem: 상품재고관리: 정렬함수
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 오름차순 또는 내림차순으로 정렬하는 함수 item_sort()를 정의하고, 호출하여 Output Sample과 같이 출력해보세요. 머리말 부분을 출력할때에는 앞서 정의한 preface()함수를 이용하세요.작성하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 1
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 오름차순(1) 내림차순(2):
#
# 현재 상품 리스트
# ['감귤', '바나나', '베개', '빵', '우유', '음료수', '이불', '장갑', '장난감', '커피', '화장지']
# ==========================================================================================
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 2
# ```
# Output Sample
#
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
# 오름차순(1) 내림차순(2):
#
# 현재 상품 리스트
# ['화장지', '커피', '장난감', '장갑', '이불', '음료수', '우유', '빵', '베개', '바나나', '감귤']
# ==========================================================================================
# ```

# %%
#Todo



proName()
preface()
item_sort()
preface()

# %% [markdown]
# ### Problem: 상품재고관리: 종합
# 😄 변수 product에 상품 목록이 리스트로 저장되어 있습니다. 상품명을  추가, 삽입, 삭제, 검색, 정렬하는 상품재고관리 프로그램을 작성하시오. 앞서 정의한 preface(), item_apnd(), item_inst()
# item_remv(), item_search(), item_sort()를 활용하여 종합적으로 동작하는 상품재고관리 프로그램을 만들어보세요.
#
# 작업번호는 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5)이며 숫자로 입력합니다.
# 상품명은 문자열로 입력합니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 1
# 사과
# 2
# 배
# 4
# 3
# 장난감
# 4
# 베개
# 4
# 피아노
# 5
# 1
# 5
# 2
# 0
# ```
#
# Output Sample
# ```
# 상품재고관리 프로그램
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 추가상품명:
# 사과 추가 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 삽입상품명:
# 삽입위치:
# 배 삽입 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '배', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 삭제상품명:
# 장난감 삭제 완료
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '배', '감귤', '화장지', '장갑', '이불', '베개', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 검색상품명:
# 베개 검색 됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '배', '감귤', '화장지', '장갑', '이불', '베개', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 검색상품명:
# 피아노 검색 안됨
#
# 현재 상품 리스트
# ['커피', '우유', '바나나', '배', '감귤', '화장지', '장갑', '이불', '베개', '음료수', '빵', '사과']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 오름차순(1) 내림차순(2):
#
# 현재 상품 리스트
# ['감귤', '바나나', '배', '베개', '빵', '사과', '우유', '음료수', '이불', '장갑', '커피', '화장지']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 오름차순(1) 내림차순(2):
#
# 현재 상품 리스트
# ['화장지', '커피', '장갑', '이불', '음료수', '우유', '사과', '빵', '베개', '배', '바나나', '감귤']
# ==========================================================================================
#
# 종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5):
# 프로그램을 종료합니다.
# ```

# %% [markdown]
# - 위의 문제들에서 제시한 상품재고관리 함수들을 모두 만들었다면 함수를 인식하도록 한번 실행시켜준 후, 아래 코드를 실행시켜주세요.

# %%
proName()

while True:
  preface()

  menu = input('종료(0) 추가(1) 삽입(2) 삭제(3) 검색(4) 정렬(5): ')
  if menu == '1':
    item_apnd()
  elif menu == '2':
    item_inst()
  elif menu == '3':
    item_remv()
  elif menu == '4':
    item_search()
  elif menu == '5':
    item_sort()
  else:
    print('프로그램을 종료합니다.')
    break

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem: Dragon realm
# 😄 학교 캠퍼스를 돌아다니다가 드래곤을 만났습니다. 당신은 드래곤과 싸워야 합니다. 재미있는 아이디어로 게임을 완성해주세요.
#
# 아이디어 예)
# - 당신은 총 6번 공격할 수 있습니다.
# - Dragon의 초기 체력은 100입니다.
# - 당신의 공격력은 1~30사이의 숫자 중 무작위로 선택된 하나의 값이며 그 값만큼 Dragon의 체력을 소진시킬 수 있습니다.
# - Dragon의 체력이 0 이하가 되면 6번 공격을 채우지 않았어도 공격을 멈춰야 하며 당신은 승리자가 됩니다.
# - 6번의 공격 이후 Dragon의 체력이 0 이하이면 당신은 승리자가 되지만, 0보다 크면 당신은 Dragon에게 잡아 먹히게 됩니다.
#
# 먼저 조교님이 게임을 실행시켜 보여주세요. 아래 두 줄의 코드는 조교님 컴퓨터에서만 실행됩니다.
#
# ```
# import dragon
# dragon.gameStart()
# ```

# %% [markdown]
# ### (함께) intro() 함수 만들기
# 😄 아래의 코드를 intro()함수로 만들고 호출해주세요. 한 줄 한 줄 출력될때 마다 시간차를 1초씩 줍니다. 시간차를 주기 위해서는 time 모듈을 불러와야 합니다. 일반적으로 import 코드는 함수정의 파트에 포함시키지 않고 함수 밖에 써줍니다. 전달인자와 반환은 없습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# You are in a land full of dragons.
# In front of you, you see two caves.
# In one cave, the dragon is friendly,
# and will share his treasure with you.
# The other dragon is greedy and hungry,
# and will eat you on sight.
# ```

# %%
import time
time.sleep(1)
print('You are in a land full of dragons.')
time.sleep(1)
print('In front of you, you see two caves.')
time.sleep(1)
print('In one cave, the dragon is friendly,')
time.sleep(1)
print('and will share his treasure with you.')
time.sleep(1)
print('The other dragon is greedy and hungry,')
time.sleep(1)
print('and will eat you on sight.')

# %% [markdown]
# ### (스스로) intro2() 함수 만들기
# 😄 아래의 코드를 intro2()함수로 만들고 호출해주세요. 한줄 출력시 시간차는 1초로 줍니다.전달인자와 반환은 없습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# You approach the cave...
# It is dark and spooky...
# A large dragon jumps out in front of you!
# He opens his jaws and...
# ```

# %%
print('You approach the cave...')
time.sleep(1)
print('It is dark and spooky...')
time.sleep(1)
print('A large dragon jumps out in front of you!')
time.sleep(1)
print('He opens his jaws and...')

# %% [markdown]
# ### (스스로) dragon_treasure() 함수 만들기
# 😄 아래의 코드를 dragon_treasure()함수로 만들고 호출해주세요. 전달인자와 반환은 없습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# Gives you his treasure!
# 그림생략...
# ```

# %%
print('Gives you his treasure!')
print('''
                    __/>^^^;:,'
    .    \'    ,      /-.       :,/|/|'
    _______     __/ ^         :,/ \__'
_ ./_|___|_\. _(~             ;/ /  /'
    \ \   / /    `-\'--._       / / ,<  ___'
    \ \' \' /   ,__.   /=\     /  _/  >|_\'.'
        \ " /     `_ `--------\'    __ / \',\ \\'
        \./   ,_// ,---_____,   ,_  \_  ,| |'
        V     `--\' |=|           \._/ ,/  |'
                    \=\            `,,/   |'
                    \=\            ||    /'
                        \=\____       |\    \\'
                        / \/    `     <__)    \\'
                        | |                    |'
                    ,__\,\                   /'
                    ,--____>    /\.         ./'
                    \'-__________>  \.______/'
''')

# %% [markdown]
# ### (스스로) dragon_fire() 함수 만들기
# 😄 아래의 코드를 dragon_fire()함수로 만들고 호출해주세요. 전달인자와 반환은 없습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# Fire breathing dragon!!!!
# 그림생략...
# ```

# %%
print('Fire breathing dragon!!!!')
print('''
    (  )   /\   _                 (    '
    \ |  (  \ ( \.(               )                      _____'
    \  \ \  `  `   ) \             (  ___                 / _   \\'
    (_`    \+   . x  ( .\            \/   \____-----------/ (o)   \_'
- .-               \+  ;          (  O                           \____'
                            )        \_____________  `              \  /'
(__                +- .( -\'.- <. - _  VVVVVVV VV V\                 \/'
(_____            ._._: <_ - <- _  (--  _AAAAAAA__A_/                  |'
    .    /./.+-  . .- /  +--  - .     \______________//_              \_______'
    (__ \' /x  / x _/ (                                  \___\'          \     /'
    , x / ( \'  . / .  /                                      |           \   /'
    /  /  _/ /    +                                      /              \/'
    \'  (__/                                             /                  \\'
''')

# %% [markdown]
# ### (함께) ChooseCave() 함수 만들기
# 😄 동굴 번호 1번과 2번 중에 하나를 입력받습니다. 입력값이 1 또는 2가 아니면 올바른 값을 입력 할 때까지 계속되는 ChooseCave() 함수를 정의하세요. 입출력은 함수 내에서 이루어집니다. 전달인자는 없고 올바른 값이 입력되었다면 입력받은 번호(cave)를 반환합니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 3
# 4
# hello
# 1
# ```
# Output Sample
# ```
# Which cave will you go into?(1 or 2):
# Which cave will you go into?(1 or 2):
# Which cave will you go into?(1 or 2):
# Which cave will you go into?(1 or 2):
# You choose the number 1.
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 100
# 2
# ```
# Output Sample
# ```
# Which cave will you go into?(1 or 2):
# Which cave will you go into?(1 or 2):
# You choose the number 2.
# ```

# %%
#Todo



cave = ChooseCave()

# %% [markdown]
# ### (함께) CheckCave() 함수 만들기
# 😄 입력받은 번호가 랜덤 수와 같으면 'Gives you his treasure!'를 출력하고 다르면 'Fire breathing dragon!!!!'를 출력하는 CheckCave() 함수를 정의하시오. 랜덤수는 1과 2에서 랜덤하게 생성됩니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sampel
# ```
# 1
# ```
#
# Output Sample
# ```
# Input Cave:
# Fire breathing dragon!!!!
# 그림생략
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sampel
# ```
# 2
# ```
#
# Output Sample
# ```
# Input Cave:
# Gives you his treasure!
# 그림생략
# ```

# %% [markdown]
# ### (스스로) replayGame() 함수 만들기
# 😄 입력값이 'yes', 'Yes', 'y', 'Y', 'YES' 중 하나라면 True를, 하나도 포함되지 않았다면 False를 <font color="red">반환</font>하는  replayGame() 함수를 정의하세요.
# 입력은 함수 안에서 받습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# yes
# ```
# Output Sample
# ```
# Do you want to play again?(yes or no):
# Restart the game
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# No
# ```
# Output Sample
# ```
# Do you want to play again?(yes or no):
# Thank you!
# ```

# %%
#Todo


if replayGame():
  print('Restart the game')
else:
  print('Thank you!')

# %% [markdown]
# ### (함께) gameStart() 함수
# 😄 앞에서 정의했던 모든 함수들을 게임 순서대로 호출하여 전체 dragon realm게임을 동작시키는 gameStart() 함수를 만드시오.

# %%
#1. 필요한 두개의 모듈을 import 시킵니다.
import time
import random

#2. intro()함수 정의 코드만 넣어줍니다.



#3. intro2()함수 정의 코드만 넣어줍니다.



#4. dragon_treasure()함수 정의 코드만 넣어줍니다.





#5. dragon_fire()함수 정의 코드만 넣어줍니다.





#6. ChooseCave()함수 정의 코드만 넣어줍니다.



#7. CheckCave()함수 정의 코드만 넣어줍니다.





#8. replayGame()함수 정의 코드만 넣어줍니다.



#. gameStart()함수를 정의해줍니다.

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: pw_check()함수 만들기
# 😄 사용자가 입력한 비밀번호가 "pythonisfun!"과 같은지 판별하는 pw_check()함수를 정의하시오. 입력과 출력은 함수 밖에서 이루어지며, 결과는 True, False로 반환합니다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# pythoniseasy!
# ```
#
# Output Sample
# ```
# Input password:
# False
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# pythonisfun!
# ```
#
# Output Sample
# ```
# Input password:
# True
# ```

# %% [markdown]
# ### Problem: id_check()함수 만들기
#
# 😄 문자열이 주어졌을 때, 그것이 아래의 <아이디 조건>들에 모두 부합하는지 확인하는 id_check()함수를 정의하시오. 입력과 출력은 함수 밖에서 이루어지며, 결과는 True, False로 반환합니다.
# ```
# <아이디 조건>
# (1) 문자열의 길이는 9-11 (inclusive).
# (2) 문자열의 첫 7글자는 'student' (case sensitive).
# (3) 문자열의 마지막 1글자는 '!'.
# ```
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# student33!
# ```
#
# Output Sample
# ```
# Input ID:
# True
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# student!
# ```
#
# Output Sample
# ```
# Input ID:
# False
# ```

# %% [markdown]
# ### Problem: login_check()함수 만들기
#
# 😄 앞에서 정의한 id_check()와 pw_check()를 활용하여
# id와 pw를 검사하는 login_check()함수를 정의하시오. ID와 pw입력은 함수 밖에서 이루어집니다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# student!
# pythoniseasy!
# ```
#
# Output Sample
# ```
# Input ID:
# Input password:
# Incorrect ID
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# student33!
# pythoniseasy!
# ```
#
# Output Sample
# ```
# Input ID:
# Input password:
# Incorrect password
# ```
# <font color='blue'>`test case-3`</font>
#
# Input Sample
# ```
# student33!
# pythonisfun!
# ```
#
# Output Sample
# ```
# Input ID:
# Input password:
# Success
# ```

# %% [markdown]
# ### Problem: mySum()함수 만들기
#
# 😄 파이썬에는 sum()함수가 있습니다.
# sum()함수는 sum(range(start, end)), sum([10,20,30])과 같이 범위 또는 반복가능한 숫자형데이터)를 넣어주면 합을 반환해줍니다. sum() 함수와 똑같이 동작하는 mySum()함수를 정의하시오. 입력은 정수 2개가 콤마로 구분하여 들어옵니다. 첫 번째 숫자는 range() 함수의 start값으로, 두 번째 숫자는 end값으로 사용됩니다.
# 출력은 start부터 end까지 수열의 합을 구합니다.
# 입력과 출력은 함수 밖에서 이루어집니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 1,100
# ```
# Output Sample
# ```
# Input:
# Output: 5050
# ```
# <font color='blue'>`test case-2`</font>
# ---
# Input Sample
# ```
# 50,100
# ```
# Output Sample
# ```
# Input:
# Output: 3825
# ```

# %% [markdown]
# - 아래 sum()함수는 파이썬의 내장함수입니다.

# %%
start=1
end=100
print(sum(range(start, end)))
print(sum([10,20,30]))

# %% [markdown]
# - mySum() 함수를 정의했다면 아래 코드와 같이 전달인자로 리스트 [10,20,30,40]를 넣어서 잘 동작하는지 확인해보시오.

# %%
mySum([10,20,30,40])

# %% [markdown]
# ### Problem: myMax() 함수 만들기
# 😄 파이썬에서는 max()함수가 있습니다. max()함수는  max(data)과 같이 data를 넣어주면 data에서 최대값을 반환해줍니다. max() 함수와 똑같이 동작하는 myMax()함수를 정의하시오.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 80, 33, 95, 46, 89, 95, 84, 68, 4, 60
# ```
# Output Sample
# ```
# Input:
# Max: 95
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 31, 39, 14, 93, 51, 62, 20, 12, 9, 3
# ```
# Output Sample
# ```
# Input:
# Max: 93
# ```

# %% [markdown]
# - 아래 max()함수는 파이썬의 내장함수입니다.

# %%
print(max(31, 39, 14, 93, 51, 62, 20, 12, 9, 3))
print(max([1,40,23,12]))

# %% [markdown]
# ### Problem: comtto() 함수 만들기
# 😄 0~9까지의 숫자 가운데 중복되지 않은 4개의 정수를 랜덤으로 생성해 리스트로 만들어 반환하는 comtto()함수를 정의하시오. Output Sample의 숫자는 아래와 다를 수 있습니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# 컴또복권번호: [7, 4, 3, 6]
# ```
#
#
# <font color='blue'>`test case-2`</font>
#
# Output Sample
# ```
# 컴또복권번호: [9, 5, 0, 3]
# ```

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---
