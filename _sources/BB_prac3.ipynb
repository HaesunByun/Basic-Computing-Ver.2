# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK3: 조건문

# %% [markdown]
# **<font color='red'>안내</font>**
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 수업 이해에 도움이 됩니다.
# - <font color='blue'>문제의 소스코드를 직접 작성하여 결과가 정확하게 나오도록 구현해야 하며,
#   - etl>코딩수업>엘리스코딩 플랫폼의 해당 주차에 제출해서 점수를 받으셔야 과제제출로 인정됩니다.
#   - 제출 기한은 수업 당일 자정입니다.
#   - 출석 인정 결석의 경우, 해당 주 일요일 21시~23시에 제출할 수 있도록 엘리스가 오픈됩니다.</font>
# - 완전 실습 문제는 보너스 실습 문제입니다. 모두 풀어본 학생들이 추가 학습용으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도의 풀이를 진행하지 않습니다.
# - 질문은 사전·도전·완전 실습 문제 및 수업과 관련된 모든 내용에 대해 교수자, 조교, 튜터에게 자유롭게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한 칸의 공백이 있습니다.</font>**

# %% [markdown]
# ### 데이터 입력과 출력 예
# 😄문자열을 입력받아 출력하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: 즐거워
# ```
#
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# Say! I can do it!
# ```
# Output Sample
# ```
# 문자열:
# 출력결과: Say! I can do it!
# ```

# %%
input_data = input('문자열: ')
print(f'출력결과: {input_data}')
# Out:
# 문자열: Say! I can do it!
# 출력결과: Say! I can do it!

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 합격, 불합격 판단
#
# 😄 성적(정수)을 입력 받아 90점 이상이면 합격, 90점 미만이면 불합격 여부를 알려주는 프로그램을 작성하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 95
# ```
# Output Sample
# ```
# 성적을 입력하시오:
# 합격입니다.
# ```
#
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 76
# ```
# Output Sample
# ```
# 성적을 입력하시오:
# 불합격입니다.
# ```

# %% [markdown]
# ### Problem: 홀수, 짝수 판별하기
# 😄 자연수를 입력 받아 홀수인지 짝수인지 출력하는 프로그램을 작성하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 97
# ```
# Output Sample
# ```
# 수를 입력하시오:
# 홀수입니다.
# ```
#
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 76
# ```
# Output Sample
# ```
# 수를 입력하시오:
# 짝수입니다.
# ```

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem: (함께) 큰 수, 작은 수, 같은 수 판단하기
# 😄 두 개의 정수를 입력 받아 큰 수, 작은 수, 같은 수를 판단하여 출력하는 프로그램을 작성하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 100
# 200
# ```
# Output Sample
# ```
# FirstNum:
# SecondNum:
# 큰 수: 200 작은 수: 100
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 124
# 56
# ```
# Output Sample
# ```
# FirstNum:
# SecondNum:
# 큰 수: 124 작은 수: 56
# ```
# <font color='blue'>`Test case-3`</font>
#
# Input Sample
# ```
# 27
# 27
# ```
# Output Sample
# ```
# FirstNum:
# SecondNum:
# 두 수는 같습니다.
# ```

# %% [markdown]
# ### Problem: (스스로) BMI 계산 프로그램
# 😄신장(cm)과 체중(kg)을 입력 받아 아래 BMI(신체질량지수(Body Mass Index)) 공식을 이용하여 BMI를 계산하는 프로그램을 작성하시오. BMI가 25이상이면 비만입니다. * 단위에 주의하세요.
#
# ---
#
# ```
# 아래 공식의 단위는 킬로그램과 미터입니다.
# weight(kg)
# height(m)
#
# ```
# $ BMI = weight / height^2 $
#
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 160
# 65.2
# ```
# Output Sample
# ```
# 신장(cm):
# 체중(kg):
# BMI는 25.47
# 비만입니다. 운동으로 감량이 필요합니다.
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 170
# 55.3
# ```
# Output Sample
# ```
# 신장(cm):
# 체중(kg):
# BMI는 19.13
# 정상입니다. 꾸준한 운동으로 유지시켜주세요.
# ```

# %% [markdown]
# ### Problem: (스스로) 합격, 불합격, 과락 판단
# 😄이름과 국어, 수학, 컴퓨팅기초 점수(정수) 세 개를 입력받아 다음 조건에 따라 결과를 출력하는 프로그램을 작성하시오.
#
# - 합격: 평균이 60점 이상이고 모두 40점 이상
# - 과락: 평균이 60점 이상이나 40점 미만 과목이 있음
# - 불합격: 평균이 60점 미만
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 홍길동
# 87
# 37
# 77
# ```
# Output Sample
# ```
# 이름:
# 국어:
# 수학:
# 컴기:
# 홍길동님은 과락입니다.
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 홍길동
# 87
# 57
# 77
# ```
# Output Sample
# ```
# 이름:
# 국어:
# 수학:
# 컴기:
# 홍길동님은 합격입니다.
# ```
# <font color='blue'>`Test case-3`</font>
#
# Input Sample
# ```
# 홍길동
# 62
# 37
# 68
# ```
# Output Sample
# ```
# 이름:
# 국어:
# 수학:
# 컴기:
# 홍길동님은 불합격입니다.
# ```

# %% [markdown]
# ### Problem: (스스로) 미세먼지농도 결과
# 😄미세먼지 농도(자연수)를 입력받아 결과를 출력하는 프로그램을 작성하시오.
#
# ---
#
# ```
# - 좋음(30 이하)
# - 보통(30 초과, 80 이하)
# - 나쁨(80 초과, 150 이하)
# - 매우 나쁨(150초과)
# - 미세먼지 농도가 100 이상일 경우 `미세먼지 경계단계입니다.` 추가 출력
# ```
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 20
# ```
# Output Sample
# ```
# 미세먼지농도:
# 좋음입니다.
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 90
# ```
# Output Sample
# ```
# 미세먼지농도:
# 나쁨입니다.
# ```
#
# <font color='blue'>`Test case-3`</font>
#
# Input Sample
# ```
# 156
# ```
# Output Sample
# ```
# 미세먼지농도:
# 매우 나쁨입니다.
# 미세먼지 경계단계입니다.
# ```

# %% [markdown]
# ### Problem: (함께) 범위안 난수 발생시키기
# 😄범위의 시작 값과 끝 값을 정수로 입력 받아 그 범위에서 random 값을 출력하는 프로그램을 작성하시오. 단, 끝 값이 시작 값보다 작을 경우에는 `끝 값을 잘못 입력하셨습니다.`를 출력해야 합니다.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 100
# 200
# ```
# Output Sample
# ```
# 범위 시작:
# 범위 끝:
# 100부터 200범위에서 생성한 난수는 130 입니다.
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 100
# 50
# ```
# Output Sample
# ```
# 범위 시작:
# 범위 끝:
# 끝 값을 잘못 입력하셨습니다.
# ```

# %% [markdown]
# ### Problem: (함께) 윤년 판별하기
# 😄연도를 입력 받은 후 윤년 여부를 판별하는 프로그램을 작성하시오. 윤년이란 연도가 4로는 나누어지지만 100으로는 나누어지지 않거나, 혹은 400으로 나누어지는 연도를 말한다.
#
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 2008
# ```
# Output Sample
# ```
# 연도:
# 2008년은 윤년입니다.
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 2023
# ```
# Output Sample
# ```
# 연도:
# 2023년은 윤년이 아닙니다.
# ```

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: 환율 계산기1
# 😄금액(정수)을 입력받고 아래 통화데이터를 이용하여 입력받은 금액의 환율을 소수점 한자리까지 계산하여 출력하는 프로그램을 작성하시오.
#
# ---
#
#
# ```
# 1원(대한민국) ↔ 0.00084 달러
# 1위안(중국) ↔  0.15 달러
# 1엔(일본) ↔ 0.0094 달러
# 1페소(필리핀) ↔  0.021달러
# ```
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 5000
# ```
# Output Sample
# ```
# 금액:
# 대한민국 5000원은 4.2달러입니다.
# 중국 5000위안은 750.0달러입니다.
# 일본 5000엔은 47.0달러입니다.
# 필리핀 5000페소는 105.0달러입니다.
#
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 10000
# ```
# Output Sample
# ```
# 금액:
# 대한민국 10000원은 8.4달러입니다.
# 중국 10000위안은 1500.0달러입니다.
# 일본 10000엔은 94.0달러입니다.
# 필리핀 10000페소는 210.0달러입니다.
# ```

# %% [markdown]
# ### Problem: 환율 계산기2
# 😄금액(정수, 원화)과 변환대상국을 입력받고 아래 통화데이터를 이용하여 입력받은 금액의 환율을 소수점 한자리까지 계산하여 출력하는 프로그램을 작성하시오. 단, 변환대상국이 없다면 `죄송합니다. 아직 통화변환 서비스 대상이 아닌 국가입니다.`를 출력해야 합니다.
#
# ---
#
#
# ```
# 1원(대한민국) ↔ 0.00084 달러
# 1위안(중국) ↔  0.15 달러
# 1엔(일본) ↔ 0.0094 달러
# 1페소(필리핀) ↔  0.021달러
# ```
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 5000
# 중국
# ```
# Output Sample
# ```
# 금액(원):
# 변환대상국:
# 중국 28.0입니다.
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 5000
# 인도
# ```
# Output Sample
# ```
# 금액(원):
# 변환대상국:
# 죄송합니다. 아직 통화변환 서비스 대상이 아닌 국가입니다.
# ```

# %% [markdown]
# ### Problem: 칼로리 계산기1
# 😄체중(자연수, kg)과 운동시간(자연수, 분)을 입력받아 칼로리를 계산하는 프로그램을 작성하시오.
#
# ---
#
# ```
# METs(대사당량) 기준
# 걷기 : 4METs     조깅 : 7METs
# 계단 : 5METs     수영 : 9METs
#
# 칼로리 =((METs * 3.5 * 체중(kg)) /200)*운동시간(분)
# ```
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 60
# 10
# ```
# Output Sample
# ```
# 체중(kg):
# 운동시간(m):
# 걷기 10분은 42.0kcal 소모
# 조깅 10분은 73.5kcal 소모
# 계단오르기 10분은 52.5kcal 소모
# 수영 10분은 94.5kcal 소모
# ```

# %% [markdown]
# ### Problem: 칼로리 계산기2
# 😄체중(자연수, kg), 운동시간(자연수, 분), 운동종목을 입력받아 칼로리를 계산하는 프로그램을 작성하시오.
#
# ---
#
# ```
# METs(대사당량) 기준
# 걷기 : 4METs     조깅 : 7METs
# 계단 : 5METs     수영 : 9METs
#
# 칼로리 =((METs * 3.5 * 체중(kg)) /200)*운동시간(분)
# ```
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 60
# 10
# 걷기
# ```
# Output Sample
# ```
# 체중(kg):
# 운동시간(m):
# 운동종목(걷기, 조깅, 계단오르기, 수영):
# 걷기 10분은 42.0kcal 소모
# ```

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---
