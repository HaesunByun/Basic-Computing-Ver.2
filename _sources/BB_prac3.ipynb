# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK3: 입출력과 타입변환

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 문제의 소스코드를 작성하여 결과가 정확하게 나오면 etl>모듈>과제>에 제출하여야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 etl>모듈>과제에 설정된 기한을 확인하여 주시기 바랍니다.(일반적으로 수업당일 자정까지)</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# ## [사전 실습 문제]

# %% [markdown]
# ### Problem: 입력받아 연산하기
# 😄문자열과 숫자(양수)를 입력받아 입력받은 문자열을 숫자만큼 연속으로 출력하는 코드를 작성하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 즐거워
# 5
# ```
# Output Sample
# ```
# 문자열:
# 횟수:
# 즐거워 즐거워 즐거워 즐거워 즐거워
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
#
# ```
# 코딩은 즐거워
# 5
# ```
# Output Sample
# ```
# 문자열:
# 횟수:
# 코딩은 즐거워 코딩은 즐거워 코딩은 즐거워 코딩은 즐거워 코딩은 즐거워
# ```

# %% [markdown]
# ### Problem: 당신이 좋아하는 것들
# 😄 좋아하는 과일, 꽃, 음료를 입력받아 그 결과를 아래와 같이 출력하는 코드를 작성하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# apple
# rose
# coke
# ```
# Output Sample
# ```
# Tell me your favorite stuff.
# Your favorite fruit is
# Your favorite flower is
# Your favorite drink is
#
# You entered: apple, rose, coke
# ```

# %% [markdown]
# ## [도전 실습 문제]

# %% [markdown]
# ### Problem:(함께) 연월일 표현하기
# 😄 연월일을 입력받아 연월일 사이에 점을 삽입하여 출력하는 프로그램을 작성하시오.
#
# ---
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 2025
# 3
# 20
# ```
#
# Output
# ```
# 연도:
# 월:
# 일:
# Output: 2025.3.20
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 2024
# 3
# 18
# ```
#
# Output
# ```
# 연도:
# 월:
# 일:
# Output: 2024.3.18
# ```

# %% [markdown]
# ### Problem: (스스로) 온라인 서점 책 결제금액 계산하기
# 😄 책값, 할인율, 배송료를 입력 받아 결제 금액을 계산하는 프로그램을 작성하시오.
#
# ---
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 20000
# 10
# 3000
# ```
# Output
# ```
# 책값:
# 할인율:
# 배송료:
# 결제 금액: 21000원
# ```
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 28000
# 10
# 3000
# ```
# Output
# ```
# 책값:
# 할인율:
# 배송료:
# 결제 금액: 28200원
# ```

# %% [markdown]
# ### Problem: (함께) 숫자요일 출력하기
# 😄1234560은 각각 월화수목금토일을 의미한다. 예를 들어, 4는 목요일이다.
# 오늘을 의미하는 숫자를 입력받아 30일 후에는 무슨 요일인지 숫자로 출력하는 코드를 작성하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
#
# ```
# 4
# ```
# Output Sample
# ```
# Input:
# Output: 6
# ```
#
#
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
#
# ```
# 2
# ```
# Output Sample
# ```
# Input:
# Output: 4
# ```

# %% [markdown]
# ### Problem: (스스로)온도 변환하기
# 😄화씨온도를 입력받아 섭씨온도로, 섭씨온도를 입력받아 화씨온도로 변환하여 출력하시오. 온도 변환공식은 아래와 같다.
#
# ---
#
# ```
# c = 5.0/9.0*(f-32.0)
# f = 9.0/5.0*c+32.0
# ```
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 100
# 50
# ```
# Output Sample
# ```
# F:
# C: 37.78
#
# C:
# F: 122.0
# ```

# %% [markdown]
# ### Problem: (스스로) 앵무새 프로그램
# 😄조련사의 말을 따라하는 앵무새 프로그램을 작성하시오.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 너 이름이 뭐니?
# 난 조련사야.
# 잘따라 하는구나.
# ```
# Output Sample
# ```
# 조련사:
# 앵무새: 너 이름이 뭐니?
# 조련사:
# 앵무새: 난 조련사야.
# 조련사:
# 앵무새: 잘따라 하는구나.
# ```

# %% [markdown]
# ### Problem: (함께) 사각형의 둘레와 면적 계산하기
# 😄 사각형의 가로와 세로 길이를 입력받아 둘레와 면적을 구하는 프로그램을 작성하시오. 가로, 세로 단위는 cm이다.
#
# ---
# 둘레 공식: $2(w+h)$
#
# 면적 공식: $w*h$
#
# cm²와 같이 제곱표현은 cm² 문자열을 복사하여 사용하세요.
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 10
# 20
# ```
# Output Sample
# ```
# 너비:
# 높이:
# 둘레: 60.0cm
# 면적: 200.0cm²
# ```

# %% [markdown]
# ## [완전 실습 문제]

# %% [markdown]
# ### Problem: 부가세 계산 프로그램
#
# * 부가가치세란 상품(재화)의 거래나 서비스(용역)의 제공과정에서 얻어지는 부가가치(이윤)에 대하여 과세하는 세금이다. 부가가치세는 물건값에 포함되어 있기 때문에 실지로는 최종소비자가 부담한다.
#
# 😄 합계금액(정수)을 입력받고 아래 공식을 이용하여 입력받은 금액의 부가세액과 공급가액을 계산하는 프로그램을 작성하시오.
#
#
# ```
# 부가세액 = 합계금액 * (10/110)
# 공급가액 = 합계금액 - 부가세액
# ```
# ---
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 100000
# ```
# Output Sample
# ```
# 합계금액:
# 공급가액: 90909원
# 세액: 9091원
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 150000
# ```
# Output Sample
# ```
# 합계금액:
# 공급가액: 136364원
# 세액: 13636원
# ```

# %% [markdown]
# ### Problem: 인구수 프로젝트
# 😄인구 조사국에서 조사한 출생, 사망, 이민자는 다음과 같았다.
# - 7초마다 한 명 출생
# - 13초마다 한 명 사망
# - 45초마다 새로운 이민자
#
# x년 후의 인구를 출력하는 프로그램을 작성하시오. 현재의 인구가 312,032,486명이라고 가정한다.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 5
# ```
# Output Sample
# ```
# 몇 년 후?
# 5년 후 인구수 325932970명
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 7
# ```
# Output Sample
# ```
# 몇 년 후?
# 7년 후 인구수 331493163명
# ```

# %% [markdown]
# ### Problem: 동전 최소 개수
# 😄금액을 입력받아 최소 동전의 개수를 출력하는 코드를 작성하시오. 단, 금액은 10000원 이하, 10의 배수로 입력하고, 500원, 100원, 50원, 10원의 동전이 무한개 있다고 가정한다.
#
# ---
#
# <font color='blue'>`Test case-1`</font>
#
# Input Sample
# ```
# 9820
# ```
# Output Sample
# ```
# 금액:
# 최소 동전 개수: 24
# ```
# <font color='blue'>`Test case-2`</font>
#
# Input Sample
# ```
# 760
# ```
# Output Sample
# ```
# 금액:
# 최소 동전 개수: 5
# ```

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---
