# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---

# %% [markdown]
# # 실습 WEEK12: Pandas II

# %% [markdown]
# :::{admonition} 안내
# :class: info
#
# - 실습 문제는 사전, 도전, 완전 실습 문제로 구성되어 있습니다.
# - 사전 실습 문제는 수업 전에 미리 풀어보시면 도움이 됩니다.
# - **<font color='blue'>도전 실습 문제는 문제의 소스코드를 작성하여 결과가 정확하게 나오면 etl>모듈>과제>에 제출하여야 과제 점수를 받을 수 있습니다.</font>**
# - **<font color='red'>제출기한은 etl>모듈>과제에 설정된 기한을 확인하여 주시기 바랍니다.(일반적으로 수업당일 자정까지)</font>**
# - 완전 실습 문제는 보너스 실습 문제로 생각하시면 됩니다.  도전 실습 문제를 다 풀어본 학생들이 추가적으로 풀어보시면 도움이 됩니다.
# - 사전 실습 문제와 완전 실습 문제는 수업 시간에 별도 풀이를 하지 않습니다.
# - 질문은 사전, 도전, 완전 그리고 수업과 관련된 모든 것에  대하여 교수자 or 조교 or 튜터에게 하시면 됩니다.
# - **<font color='red'>가독성을 위해 입출력 데이터에서 콜론(:) 다음에는 항상 한칸 공백이 있습니다.</font>**
#
# :::

# %% [markdown]
# # [도전 실습 문제]

# %% [markdown]
# - 자유롭게 chatGPT 쓰셔도 됩니다.
# - chatGPT에게 어떻게 질문을 해야할지 모르겠다면 튜터님의 도움을 받으세요.

# %% [markdown]
# ## Problem: (스스로+함께)데일리 인기동영상 데이터 다뤄보기

# %% [markdown]
# 데이터 출처 :https://www.kaggle.com/rsrishav/youtube-trending-video-dataset?select=KR_youtube_trending_data.csv
#
# 데이터 설명 : 유튜브 데일리 인기동영상 (한국)
# data url : https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv

# %% [markdown]
# ### (함께) 데이터프레임으로 불러오기
# 😄 파일을 불러와 데이터프레임으로 만들어주세요.
# - 약 2분 동안 각 칼럼의 데이터를 살펴보고 파악해주세요.

# %%
import pandas as pd

# %% [markdown]
# ### (함께) chatGPT 활용하여 조회수로 정렬하기
# 😄 조회수가 가장 많은 순서대로(내림차순) 데이터를 정렬하시오.

# %%
# Out:
#                                              title   channelTitle  categoryId  \
# 30583             BTS (방탄소년단) 'Butter' Official MV    HYBE LABELS          10
# 30383             BTS (방탄소년단) 'Butter' Official MV    HYBE LABELS          10
# 30174             BTS (방탄소년단) 'Butter' Official MV    HYBE LABELS          10
# 29964             BTS (방탄소년단) 'Butter' Official MV    HYBE LABELS          10
# 29729             BTS (방탄소년단) 'Butter' Official MV    HYBE LABELS          10
# ...                                            ...            ...         ...
# 1180   Hello 2021 Korea | 크리에이터와 함께하는 Goodbye 2020  YouTube Korea          24
# 23575                        Earth Day 2021 Doodle  GoogleDoodles           1
# 22906                        Earth Day 2021 Doodle  GoogleDoodles           1
# 22222                        Earth Day 2021 Doodle  GoogleDoodles           1
# 44     Hello 2021 Korea | 크리에이터와 함께하는 Goodbye 2020  YouTube Korea          24
#
# ...

# %% [markdown]
# ### (스스로) '좋아요'/'싫어요' 상위 채널명 10개
# - chatGPT를 활용하셔도 좋습니다.

# %% [markdown]
# 😄 '좋아요'가 가장 많은 인기 동영상의 채널명 10개를 출력하시오.

# %%
# Out:
# array(['HYBE LABELS', 'BLACKPINK', 'Coldplay', 'BANGTANTV', 'SMTOWN',
#        'AdeleVEVO', 'JYP Entertainment', 'Jennierubyjane Official',
#        'Big Hit Labels', 'Lilifilm Official'], dtype=object)

# %% [markdown]
# 😄 '싫어요'가 가장 적은 인기 동영상의 채널명 10개를 출력하시오.

# %%
# Out:
# array(['LCK', "RAIN's Official Channel", '모비딕 Mobidic', '대한민국공군',
#        'SBS Radio 에라오', 'Samsung', 'BTOB 비투비 (Official YouTube Channel)',
#        '이루리 ILULIY', '허스토리 KBS', '머몌밈'], dtype=object)

# %% [markdown]
# 😄 위에서 찾은 '싫어요'가 가장 적은 인기 동영상을 만든 채널 중 가장 첫 번째 채널이 만든 영상들을 모두 출력하시오.

# %%
# Out:
# 20016     [4K] 결승전 오프닝 세리머니 머쉬베놈 x 릴보이ㅣ2021 LCK 스프링 스플릿 결승
# 20233     [4K] 결승전 오프닝 세리머니 머쉬베놈 x 릴보이ㅣ2021 LCK 스프링 스플릿 결승
# 20653     [4K] 결승전 오프닝 세리머니 머쉬베놈 x 릴보이ㅣ2021 LCK 스프링 스플릿 결승
# 20878     [4K] 결승전 오프닝 세리머니 머쉬베놈 x 릴보이ㅣ2021 LCK 스프링 스플릿 결승
# 21122     [4K] 결승전 오프닝 세리머니 머쉬베놈 x 릴보이ㅣ2021 LCK 스프링 스플릿 결승
# 21334     [4K] 결승전 오프닝 세리머니 머쉬베놈 x 릴보이ㅣ2021 LCK 스프링 스플릿 결승
# 21562     [4K] 결승전 오프닝 세리머니 머쉬베놈 x 릴보이ㅣ2021 LCK 스프링 스플릿 결승
# 21787     [4K] 결승전 오프닝 세리머니 머쉬베놈 x 릴보이ㅣ2021 LCK 스프링 스플릿 결승
# 32211    2021 LCK 서머 변경점들! 어떤 영향을 미칠까?  | 2021 LCK 서머 스...
# 32410    2021 LCK 서머 변경점들! 어떤 영향을 미칠까?  | 2021 LCK 서머 스...
# 32607    각 팀의 능력치는? 플레이오프팀 예상까지!  | 2021 LCK 서머 스플릿 롤분토...
# 32626    2021 LCK 서머 변경점들! 어떤 영향을 미칠까?  | 2021 LCK 서머 스...
# 32811    각 팀의 능력치는? 플레이오프팀 예상까지!  | 2021 LCK 서머 스플릿 롤분토...
# 32836    2021 LCK 서머 변경점들! 어떤 영향을 미칠까?  | 2021 LCK 서머 스...
# 33048    각 팀의 능력치는? 플레이오프팀 예상까지!  | 2021 LCK 서머 스플릿 롤분토...
# 33087    2021 LCK 서머 변경점들! 어떤 영향을 미칠까?  | 2021 LCK 서머 스...
# ...

# %% [markdown]
# 😄 likes가 dislikes보다 100,000개 이상 많은 영상의 제목 10개를 출력하시오.

# %%
# Out:
# 7                  [아이유의 팔레트] 팔레트에 '있지' (With ITZY) Ep.4
# 35                                       Do You Love Me?
# 41                      [JIWOO VLOG] 웨딩촬영드레스 가봉의 날 (ENG)
# 56     [GOING SEVENTEEN 2020] EP.44 TTT #1 (Hyperreal...
# 63          [CONTOUR:BACKSTAGE] NCT DREAM EP.1 (360º VR)
# 66     [2021NYEL] 2021 NEW YEAR'S EVE LIVE Relay Q&A ...
# 75     방탄소년단, 한겨울 디스코 파티 ♬Dynamite♬ㅣ2020 SBS 가요대전 in ...
# 105           [MV] 우주힙쟁이 - 한량 (feat. 비비(BIBI)) (prod.딘딘)
# 154    방탄소년단, 크리스마스를 팬들과 함께 ＜Life Goes On＞ㅣ2020 SBS 가...
# 157    ‘무대 장인’ 방탄소년단, 흑조의 유혹 ‘Black Swan’ㅣ2020 SBS 가요...
# Name: title, dtype: object

# %% [markdown]
# ## Problem: (스스로+함께)월별 교통사고 분석하기

# %% [markdown]
# ### (함께) 데이터프레임 만들기
# 😄 data가 준비되어 있습니다. 데이터프레임을 만들고 "구분" 칼럼을 인덱스로 지정하세요.
# - 약 2분 동안 각 칼럼의 데이터를 살펴보고 파악해주세요.

# %%
import pandas as pd

# 데이터 정의
data = {
    "구분": ["201401", "201402", "201403", "201404", "201405", "201406", "201407", "201408", "201409", "201410",
           "201411", "201412", "201501", "201502", "201503", "201504", "201505", "201506", "201507", "201508",
           "201509", "201510", "201511", "201512", "201601", "201602", "201603", "201604", "201605", "201606",
           "201607", "201608", "201609", "201610", "201611", "201612"],
    "승용차": [16561665.00, 16626372.00, 16691079.00, 16755786.00, 16820493.00, 16885200.00, 16949907.00,
                 17014614.00, 17079321.00, 17144028.00, 17208735.00, 17273442.00, 17338160.00, 17402870.67,
                 17467583.17, 17532295.67, 17597008.17, 17661720.67, 17726433.17, 17791145.67, 17855858.17,
                 17920570.67, 17985283.17, 18049995.67, 18114708.17, 18179420.67, 18244133.17, 18308845.67,
                 18373558.17, 18438270.67, 18502983.17, 18567695.67, 18632408.17, 18697120.67, 18761833.17,
                 18826545.67],
    "사고": [169, 145, 206, 182, 218, 233, 229, 222, 225, 210, 209, 178, 205, 175, 237, 227, 231, 207, 273,
               268, 252, 214, 199, 213, 192, 174, 217, 216, 239, 200, 227, 230, 187, 183, 200, 168],
    "사망": [7, 3, 12, 4, 17, 13, 14, 9, 15, 14, 10, 12, 8, 8, 4, 10, 9, 8, 7, 19, 10, 14, 3, 8, 5, 6, 7, 7,
               13, 12, 9, 7, 13, 10, 5, 4],
    "부상": [347, 268, 358, 360, 474, 457, 431, 447, 430, 392, 386, 329, 375, 375, 492, 486, 504, 401, 556,
               534, 501, 475, 398, 428, 387, 328, 435, 419, 522, 362, 460, 490, 347, 367, 418, 364]
}

# %% [markdown]
# ### Problem: 월별 교통사고 사상자수 구하기
# 😄 chatGPT를 활용하여 '사상자수'를 나타내는 칼럼을 새롭게 추가한 뒤, '사상자수'의 최댓값&최솟값을 출력하고 사상자수를 기준으로 오름차순 정렬한 결과를 5개의 행만 출력해보세요.<br>
# '사상자수'는 아래와 같은 공식을 통해 계산됩니다.
#
# ```
#   구분   승용차 사고 사망 부상
# 201401 16561665  169   7   347
# 201402 16626372  145   3   268
# 201403 16691079  206  12   358
#              ...
#  ```
# ```
#  단위:  승용차(대), 사고(건), 사망(명), 부상(명)
# ```
#
# ```
# 사상자수 = 사망 + 부상
#  ```

# %% [markdown]
# output sample
# ```
# 최대 사상자수: 563
# 최소 사상자수: 271
#                 승용차   사고  사망   부상  사상자수
# 구분
# 201402  16626372.00  145   3  268   271
# 201602  18179420.67  174   6  328   334
# 201412  17273442.00  178  12  329   341
# 201401  16561665.00  169   7  347   354
# 201609  18632408.17  187  13  347   360
#  ```

# %% [markdown]
# ### Problem: 월별 교통사고 위험지수 구하기
# 😄 ChatGPT를 활용하여 월별 '위험지수'을 나타내는 칼럼을 새롭게 추가해주세요.
#
# - 엘리스에서 점수를 받을 때, 이전 문제에서 생성한 '사상자수' 칼럼이 이번 문제에도 포함되어 있다는 점과, 칼럼에 순서를 지켜야 한다는 점에 유의하세요.
# - '위험지수'은 아래와 같은 공식을 통해 계산됩니다.
# ```
# 위험지수 = 10000 * ( 사고 + 20 * 사망 + 2 * 부상 ) / 승용차
#  ```
# - 그리고 위험지수의 최댓값과 최솟값을 출력하고, 데이터프레임을 '위험지수' 칼럼을 기준으로 내림차순 정렬하세요. 그 결과를 5개의 행만 출력해보세요.

# %% [markdown]
# output sample
#
#
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/sasang.PNG" width=300></div>

# %% [markdown]
# ## Problem:(스스로+함께) SF음식 안전 지수 데이터 활용해보기
# - 샌프란시스코 음식점 안전지수 데이터에는 샌프란시스코에 있는 여러 음식점들에 대한 검사 결과, 안전 점수 및 기타 관련 정보가 포함되어 있습니다.
# - 이 데이터는 샌프란시스코 보건국에서 제공하며, 음식점들이 받은 안전 점수를 바탕으로 음식점들의 위생 상태를 파악할 수 있습니다.
#
# - [San Francisco Department of Public Health](https://data.sfgov.org/Health-and-Social-Services/-Historical-Restaurant-Inspection-Scores-2016-2019/pyih-qa8i) 링크에 접속해 Export 버튼을 눌러 파일을 다운받으세요.

# %% [markdown]
# - CSV 파일 다운 받은 후 구글 코랩의 파일 - 업로드 실시하기

# %%
import pandas as pd

# %% [markdown]
# - 파일을 불러와 데이터프레임으로 만들어주세요.
# - 각 칼럼의 데이터를 살펴보고 파악하는 시간 1분 정도 드립니다.

# %%
# Out:
#        business_id                business_name     business_address  \
# 0            85936                 Laurel Court         950 Mason St
# 1             5827  HILLCREST ELEMENTARY SCHOOL       810 SILVER Ave
# 2            94910                Ike's Kitchen     800 Van Ness Ave
# 3            64667           Jasmine Rae Bakery  1890 Bryant St #309
# 4            97722           THE CHURRO FACTORY        PIER 39  K-01
# ...            ...                          ...                  ...
# 53968        70220            Trader Joe's #200         1095 Hyde St
# 53969        95021                   Wing Wings        422 Haight St
# 53970        78289              Sam Jordans Bar         4004 03rd St
# 53971       100887            ASIA CHINESE FOOD          350 BAY ST.
# 53972        15120       Nordstrom Espresso Bar    865 Market Street
#
#        business_city business_state business_postal_code  business_latitude  \
# ...

# %% [markdown]
# ### (함께+스스로)상위 5개 요소 뽑기

# %% [markdown]
# 😄 (함께)가장 빈번하게 등장하는 상위 5개의 상호명을 리스트로 만들고 출력하시오.

# %% [markdown]
# - value_counts() 함수를 통해 열의 각 값(value)에 대한 발생 빈도를 알아낼 수 있습니다.
# - 각 상호명만 가져와야 하며, 빈도 수 자체가 아닌 이름을 출력해야 합니다.
#
# ```
# ["Peet's Coffee & Tea", "McDonald's", 'Whole Foods Market', 'Jamba Juice', 'Mixt Greens/Mixt']
#  ```

# %% [markdown]
# 😄 (스스로)가장 빈번하게 등장하는 주소를 리스트로 만들고 출력하시오.
# ```
# ['428 11th St', 'Off The Grid', '3251 20th Ave', '24 Willie Mays Plaza', '1355 Market St']
# ```

# %% [markdown]
# ### (함께)개수 구해 내림차순 정렬하기

# %% [markdown]
# 😄 각 우편번호(ZIP 코드)에 속한 레스토랑이 몇 개인지 구해 내림차순으로 정렬하세요.
#
# - 인덱스를 우편번호로 하고, 해당 우편번호의 개수를 값을 출력하세요.
# - size()를 통해 개수를 셀 수 있습니다.
# - 엘리스에서는 print()함수로 출력해주세요.

# %%
#현재 셀의 출력 결과는 지우지 않고 남겨두기 위해,
#코드는 아래 셀에 작성해주세요.
# Out:
# business_postal_code
# 94110         5921
# 94103         4868
# 94102         3789
# 94109         3692
# 94133         3325
#               ...
# 94105-2907       2
# 95105            2
# 94122-1909       2
# 94105-1420       1
# 94621            1
# Length: 62, dtype: int64

# %%
# 이곳에 코드를 작성해주세요.

# %% [markdown]
# ### (함께)평균 계산하여 새로운 데이터프레임 만들기

# %% [markdown]
# 😄 각 우편번호 별 레스토랑의 음식 안전 점수의 평균을 계산하여 새로운 데이터프레임을 만드세요. 이 데이터프레임은 business_postal_code와 average_score를 열을 갖게 해주세요.
#
#
# - **groupby()**와 **mean()** 함수를 사용하여 그룹별 평균을 계산합니다.
# - 5개만 출력하세요.
# - 엘리스에서는 print()함수로 출력해주세요.

# %%
#현재 셀의 출력 결과는 지우지 않고 남겨두기 위해,
#코드는 아래 셀에 작성해주세요.
# Out:
#   business_postal_code  average_score
# 0                00000           93.0
# 1                64110           85.0
# 2                92672           84.0
# 3                94013           96.5
# 4                94014            NaN

# %%
# 이곳에 코드를 작성해주세요.

# %% [markdown]
# ### (스스로)음식 안전 점수로 필터링하기

# %% [markdown]
# 😄 inspection_score 열에서 음식 안전 점수가 80에서 85 사이인 레스토랑만 필터링하고, 그들의 상호명과 음식 안전 점수를 출력하세요.

# %%
#현재 셀의 출력 결과는 지우지 않고 남겨두기 위해,
#코드는 아래 셀에 작성해주세요.
# Out:
#                                     business_name  inspection_score
# 60                                   Fools Errand              84.0
# 89                                    Soma Eats 2              85.0
# 96                                     Tacos Club              83.0
# 103                                   Schroeder's              83.0
# 110                                 SAFEWAY #1490              82.0
# ...                                           ...               ...
# 53850                           CHASE LUCK BAKERY              84.0
# 53857                            TASTY RESTAURANT              84.0
# 53863  Domingo's International Kitchen and Fusion              82.0
# 53925                             People's Bistro              85.0
# 53944                              Casa Lucas MKT              80.0
#
# [8135 rows x 2 columns]

# %%
# 이곳에 코드를 작성해주세요.

# %% [markdown]
# ### (스스로) 상호명 필터링하기

# %% [markdown]
# 😄 business_name에 "Coffee"라는 단어가 포함된 레스토랑만 필터링하여 상호명과 주소를 출력하세요.
#
# -  **str.contains()** 메서드를 사용하여 특정 문자열이 포함된 행을 필터링 할 수 있습니다.

# %%
#현재 셀의 출력 결과는 지우지 않고 남겨두기 위해,
#코드는 아래 셀에 작성해주세요.
# Out:
#                         business_name           business_address
# 163                   Equator Coffees                222 02nd St
# 334               Peet's Coffee & Tea                370 04th St
# 375                   House of Coffee            1618 Noriega St
# 385                      Grand Coffee            2663 Mission St
# 404                      Grand Coffee            2663 Mission St
# ...                               ...                        ...
# 53869         Hole in the Wall Coffee               524 Union St
# 53883             Peet's Coffee & Tea  1400 Mission St Suite 130
# 53930                  Coffee Mission               3325 24th St
# 53935                Starbucks Coffee               442 Geary St
# 53951  Joey and Pat's Bakery & Coffee             2499 Folsom St
#
# [1306 rows x 2 columns]

# %%
# 이곳에 코드를 작성해주세요.

# %% [markdown]
# ### (스스로) 우편번호 기준으로 그룹화하기

# %% [markdown]
# 😄 restaurant 데이터프레임을 business_name을 기준으로 그룹화하고, 각 그룹에 대해 고유 우편번호 개수를 계산하여 출력하세요.
#
# - **groupby()**와 **nunique()**를 사용하여 고유 우편번호의 개수를 구할 수 있습니다.
# - 인덱스는 0부터 시작해서 정수인덱스를 가져야 합니다.
# - 칼럼의 이름은 'business_name'과 'postal_code_count'여야 합니다.
# - 5개의 행만 출력합니다.

# %%
#현재 셀의 출력 결과는 지우지 않고 남겨두기 위해,
#코드는 아래 셀에 작성해주세요.
# Out:
#                business_name  postal_code_count
# 0  #1 VERJUS CAVE, #2 VERJUS                  1
# 1          100137 Cloud Club                  1
# 2          111 Minna Gallery                  1
# 3     12 Tribes Kosher Foods                  1
# 4                1428 Haight                  1

# %%
# 이곳에 코드를 작성해주세요.

# %% [markdown]
# # [완전 실습 문제]

# %% [markdown]
# ## Problem: ChatGPT를 활용하여 Titanic 데이터 전처리하기

# %% [markdown]
# ## 1.(함께)데이터 불러오기

# %%
import pandas as pd

url_1 = 'https://raw.githubusercontent.com/HaesunByun/common/main/data/titanic_train.csv'
url_2 = 'https://raw.githubusercontent.com/HaesunByun/common/main/data/titanic_test.csv'

train = pd.read_csv(url_1, index_col=0)
test = pd.read_csv(url_2, index_col=0)

# %% [markdown]
# 😄 데이터프레임 확인하기
# - .shape으로 train데이터와  test 데이터의 데이터프레임 모양을 확인해보세요.

# %% [markdown]
# 😄 데이터 확인하기
# - .head()로 train, test 데이터프레임의 5개 행을 확인해보세요.
# - train 데이터에는 있고, test 데이터에는 없는 칼럼을 확인해보세요.
#
# ```
# - passenger ID
# - Pclass: 티켓 클래스. (1 = 1st, 2 = 2nd, 3 = 3rd)
# - Name: 이름
# - Sex: 성별
# - Age: 나이(세)
# - Sibsp (Siblings and spouse): 함께 탑승한 형제자매, 배우자 수 총합
# - Parch (Parents and children): 함께 탑승한 부모, 자녀 수 총합
# - Ticket: 티켓 번호
# - Fare: 탑승 요금
# - Cabin: 객실 번호
# - Embarked: 탑승 항구
# ```

# %% [markdown]
# 😄 데이터 확인하기
# - .info()로 데이터의 전반적인 것을 확인하시오.

# %% [markdown]
# 😄 데이터 확인하기
# - .isnull().sum()으로 결측 개수를 확인해보세요.

# %% [markdown]
# ## 2.데이터 전처리
# - 데이터 전처리는 데이터의 결측치 및 이상치를 확인하거나 제거하고 불일치되는 부분을 일관성 있는 데이터의 형태로 전환하는 과정을 데이터의 전처리라고 한다.
# - 데이터 전처리가 필요한 이유
#   - 분석에 불필요한 데이터는 삭제한다.(예: 타이타닉 데이터에서 이름)
#   - 머신러닝 알고리즘은 텍스트를 읽을 수 없는 경우가 많다. 텍스트를 숫자화 시킨다.(예: 타이타닉 데이터에서 성별, 선착장)
#   - 결측값이 있는 경우 채워넣거나 없애야 한다.(예: 타이타닉 데이터에서 나이, 요금, 객실번호, 티켓번호)
#   - 그 밖의 왜곡된 분석결과를 방지하기 위해, 또는 머신러닝에서 제대로 된 모델 학습을 위해 전처리 작업이 이루어진다.

# %% [markdown]
# 😄😄😄😄😄 이 수업에서는 여러분이 무슨 작업을 해야 하는지를 이미 지정해 놓았지만 즉, '무엇을 하시오' 목적이 곧 chatGPT의 질문이 되고 있지만, 실제로는 여러분이 데이터를 확인한 후 목적이 무엇이고 chatGPT에게 무슨 질문을 할것인지를 생각해 내야 하는 것이 데이터사고력 가운데 하나입니다.

# %% [markdown]
# ### 이름 전처리(함께)
# - 😄 chatGPT를 활용하여 이름에서 의미있는 정보인 호칭(Mr. Mrs.  등)을 'Title'이라는 칼럼에 저장하세요.

# %% [markdown]
# - 😄 chatGPT를 활용하여 'Title' 칼럼에서 동일한 값을 가진 데이터의 개수를 카운트하시오.
# - hint: value_counts() 함수

# %% [markdown]
# - 😄 chatGPT를 활용하여 호칭을 숫자화 하세요.

# %%
# 'Title'을 숫자로 매핑하여 변환
title_mapping = {'Mr':0, 'Miss':1, "Mrs": 2,
                 'Master': 3, 'Dr':3, 'Rev': 3, 'Major': 3, 'Col': 3, 'Mlle':3, 'Capt':3, 'Sir':3, 'Lady':3,
                 'Mme':3, 'Countess': 3, 'Don': 3, 'Jonkheer': 3, 'Ms':3, 'Dona':3 }
#Todo

# %% [markdown]
# - 😄 chatGPT를 활용하여 불필요한 'Name' 칼럼을 삭제해보세요.

# %% [markdown]
# ### 성별 숫자화(스스로)
# 😄 chatGPT를 활용하여 성별(Sex) 열을 남자는 0, 여자는 1로 매핑하여 변환해보세요.

# %% [markdown]
# ### Age Null 채우고 분류하기(함께)

# %% [markdown]
# - 😄 chatGPT를 활용하여 나이의 분포를 히스토그램 그래프로 확인해보시오.

# %% [markdown]
# - 😄 chatGPT를 활용하여 Age의 결측값(누락데이터) 갯수를 확인해보시오.

# %% [markdown]
# - 😄 chatGPT를 활용하여 Age의 결측값을 채우시오. 이때 기준은 Title과 Age에 대하여 그룹핑한 후, 중앙값으로 채우시오.

# %% [markdown]
# - Age의 null 갯수를 확인해본다.

# %% [markdown]
# - 😄 chatGPT를 활용하여 'Age' 칼럼의 나이를 0~9세는 0, 10대는 1, 20대는 2, 30대는 3, 40대는 4, 50대는 5, 60대 이상은 6으로 변경하시오.

# %% [markdown]
# ### 선착장 숫자화(스스로)

# %% [markdown]
# - 😄 'Embarked'(항구) 칼럼의 데이터를 head(), sum(), size를 통해 파악해보시오.

# %% [markdown]
# - 😄 chatGPT를 활용하여 'Embarked'의 결측값을 가장 많은 사람들이 출입했던 항구로 채우시오.

# %% [markdown]
# - 😄 chatGPT를 활용하여 선착장을 아래와 같이 숫자화하시오.
# ```
# 'S': 0, 'C': 1, 'Q':2
# ```

# %% [markdown]
# ### Fare Null 채우기(함께)
# - 😄 Fare의 스케일이 넓어서 이를 좁혀보자. chatGPT를 활용하여 'Fare' 칼럼을 다음과 같이 숫자화 하시오.
# ```
# 0~19 : 0
# 20~39 : 1
# 40~99 : 2
# 100~ : 3

# %% [markdown]
# ### Cabin 삭제하기 & Ticket 삭제하기(스스로)

# %% [markdown]
# - 😄 'cabin'은 결측값이 많고 데이터로 유의미한 결과를 얻기 어려우므로  chatGPT를 활용하여 삭제하시오. 'Ticket'도 삭제하시오.

# %% [markdown]
# ## 3.전처리 된 데이터 저장하기(함께)
#
# - csv 파일로 저장할 때,
#   - csv파일로 저장 pd.to_csv('파일명')
#
# - excel 파일로 저장할 때,
#   - pd.to_excel('파일명')

# %% [markdown]
# - 😄 chatGPT를 활용하여 'mod_titanic_train.csv'로 저장하세요.

# %% [markdown]
# ## 4.(함께) 상관관계 확인
# - 상관관계의 정도는 상관계수로 정량화해서 파악할 수 있다.
# - 상관계수(Correlation Coefficient)는 corrcoef( )나 corr()를 통해 확인한다.
#   - np.corrcoef(x, y): 상관 계수행렬을 반환한다.(numpy 모듈)
#   - df.corr(): 모든 행렬들간 상관계수의 행렬을 보여준다.(pandas 모듈)
#
# ```
# - 1.0 <= r < -0.7: 매우 강한 음의 상관관계
# - 0.7 <= r < -0.3: 강한 음의 상관관계
# - 0.3 <= r < -0.1: 약한 음의 상관관계
# - 0.1 <= r <= 0.1: 상관 관계 없거나 무시할만 함
# - 0.1 < r <= +0.3: 약한 양의 상관관계
# - 0.3 < r <= 0.7: 강한 양의 상관관계
# - 0.7 < r <= 1.0: 매우 강한 양의 상관관계
# ```

# %% [markdown]
# ## Problem: 비식별화

# %% [markdown]
# 데이터 3法이 등장하면서, 개인정보의 비식별화 필요성이 곳곳에서 제기되고 있다. 개인정보 비식별화를 위해 가장 많이 쓰이는 기법 가운데 하나는 k-익명성이다. k-익명성이란, 모든 식별자가 동일해 구분이 불가능한 경우가 k개 이상 존재함을 뜻한다.
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/pandas1.png" height=200 style="width:400px;">
# </div>

# %% [markdown]
# 상단 좌측의 경우, 식별자가 (M / 20s / Y)인 경우가 셋이며 (F / 30s / Y)인 경우가 둘이다.
# 즉, 구분이 불가능한 경우가 적어도 둘 존재하므로 2-익명성을 충족한다고 볼 수 있다.
# 반면 상단 우측의 경우, 모든 식별자가 동일한 경우가 하나도 없어 2-익명성에 위배된다.
#
# 쇼핑몰을 운영하고 있는 형원이는 자사 고객의 개인정보 비식별화 정도를 검토하고자 한다.
# info.csv에 고객의 정보가 담겨 있으며, ID를 제외한 세 개 열만이 식별자에 해당한다고 한다.
# k를 입력받아, info.csv의 정보가 k-익명성을 충족하는지 출력하는 프로그램을 작성하시오.
#
# info.csv는 다음의 Link를 통하여 내려받을 수 있다.
#
# https://raw.githubusercontent.com/HaesunByun/common/main/data/info.csv
#
# ---
# Input Sample
# ```
# 7
# ```
# Output Sample
# ```
# YES
# ```
#
# ---
# Input Sample
# ```
# 8
# ```
# Output Sample
# ```
# YES
# ```
#
# ---
# Input Sample
# ```
# 9
# ```
# Output Sample
# ```
# NO
# ```

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.101 컴퓨팅 기초: 처음 만나는 컴퓨팅(First Adventures in Computing)</font>
#
# ---
